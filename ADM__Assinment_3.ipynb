# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashwitha2305/ADM/blob/main/ADM__Assinment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/customer_purchases.csv')

# %%
df
# Out:
#      Customer_ID  Age  Gender  Annual_Income  Spending_Score  \
# 0              1   58    Male      117383.70              11
# 1              2   25    Male       94947.76              61
# 2              3   19  Female      112576.38               3
# 3              4   65    Male       43673.73              96
# 4              5   35    Male       36250.18              70
# ..           ...  ...     ...            ...             ...
# 195          196   58    Male       53750.05              23
# 196          197   37    Male      107964.00              39
# 197          198   58    Male       47825.66               2
# 198          199   50  Female      115120.41              91
# 199          200   56  Female       62156.48              69
#
#      Purchase_Frequency
# 0                     5
# 1                     9
# 2                     2
# 3                     2
# 4                    18
# ..                  ...
# 195                  18
# 196                   5
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df['Annual_Income'], bins=10,edgecolor="black")
plt.xlabel('Annual Income')
plt.ylabel('Frequency')
plt.title('Distribution of Annual Income')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Purchase_Frequency'], df['Spending_Score'])
plt.xlabel('Purchase Frequency')
plt.ylabel('Spending Score')
plt.title('Purchase Frequency vs. Spending Score')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
numerical_features = df[['Annual_Income', 'Spending_Score', 'Purchase_Frequency']]
correlation_matrix = numerical_features.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['Spending_Score'])
plt.title('Box Plot of Spending Score')
plt.show()

# %%
outliers = df[(df['Spending_Score'] < 10) | (df['Spending_Score'] > 90)]
print(outliers)
# Out:
#      Customer_ID  Age  Gender  Annual_Income  Spending_Score  \
# 2              3   19  Female      112576.38               3
# 3              4   65    Male       43673.73              96
# 5              6   33  Female       99988.70               7
# 9             10   24  Female      112448.73               9
# 10            11   61  Female       98238.65             100
# 12            13   52    Male       86990.71               6
# 13            14   23    Male       93505.75              97
# 14            15   55    Male       44816.72               4
# 17            18   19    Male       58254.17               3
# 30            31   44  Female       97332.66              99
# 35            36   69  Female       53114.99              96
# 36            37   18    Male       22760.05              92
# 38            39   69    Male       46121.52             100
# 43            44   35    Male       54568.71               4
# ...
